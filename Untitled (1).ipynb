# %%
# %pylab
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
#import mplcursors
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# Lê os dados da API do cartola
response = requests.get('https://api.cartolafc.globo.com/atletas/mercado')
data = json.loads(response.text)
atletas = pd.DataFrame(data['atletas'])
times = pd.DataFrame(data['clubes']).T

# %%
# Remove as colunas desnecessarias
atletas.drop(['atleta_id','scout', 'slug', 'apelido_abreviado', 'nome', 'foto'], axis=1, inplace=True)
times.drop(['abreviacao', 'escudos', 'nome_fantasia'], axis=1, inplace=True)
atletas = atletas[['apelido', 'clube_id', 'posicao_id', 'preco_num', 'pontos_num', 'variacao_num', 'media_num', 'rodada_id', 'jogos_num','status_id']]

# %%
atletas.posicao_id = atletas.posicao_id.map({1:'Goleiro', 2:'Lateral', 3:'Zagueiro', 4:'Meia', 5:'Atacante', 6:'Tecnico'})
times_id = times['id'].to_list()
times_nome = times['nome'].to_list()
dictionary = dict(zip(times_id, times_nome))
atletas.clube_id = atletas.clube_id.map(dictionary)
#renomeia as colunas
atletas.rename(columns={'clube_id': 'clube', 'posicao_id': 'posicao', 'preco_num': 'preco', 'pontos_num': 'pontos', 'variacao_num': 'variacao', 'media_num': 'media', 'rodada_id': 'rodada', 'jogos_num': 'jogos'}, inplace=True)

# %%
atletas.drop(index=atletas[atletas.apelido=='Rodallega'].index,axis=0,inplace=True)
atletas=atletas[atletas.status_id==7].reset_index()
atletas.drop(['index','status_id'], axis=1, inplace=True)
atletas.reset_index()
# Out:
#      index            apelido         clube   posicao  preco  pontos  \
# 0        0             Vargas   Atlético-MG  Atacante   7.58    9.00
# 1        1            Cleiton    Bragantino   Goleiro   8.64   -0.50
# 2        2       Nino Paraíba         Bahia   Lateral   8.80    7.10
# 3        3  Douglas Friedrich     Juventude   Goleiro   4.70    0.00
# 4        4         Óscar Ruíz         Bahia      Meia   4.33    4.70
# ..     ...                ...           ...       ...    ...     ...
# 216    216      Paulo Autuori  Athlético-PR   Tecnico   7.96    2.69
# 217    217       Róger Guedes   Corinthians  Atacante  15.17    4.50
# 218    218     Léo Baptistão         Santos  Atacante   7.92    0.90
# 219    219             Marcão    Fluminense   Tecnico   9.82    3.43
# 220    220             Dawhan     Juventude      Meia   3.18    3.70
#
#      variacao  media  rodada  jogos
# 0        0.73   4.48      21      7
# 1       -0.98   3.97      21     17
# 2        0.32   3.11      21     16
# 3       -1.30   0.00      21      1
# 4        0.73   0.67      21     17
# ..        ...    ...     ...    ...
# 216     -0.60   2.69      21      1
# 217     -0.19   8.00      21      3
# 218      0.03   2.73      21      3
# 219      0.08   4.05      21      5
# 220      1.12   0.20      21      6
#
# [221 rows x 10 columns]

# %%
#dados.id=list(range(0,len(dados)))
#dados.index=list(range(0,len(dados)))
#random.choice(dados.loc[dados.posicao=='Goleiro']['index'])

# %%
#atletas = atletas[atletas.status_id==7]#drop(['status_id'], axis=1)
#atletas = atletas.drop(['status_id'], axis=1)
dados.iloc[populacao[i]].score_atleta.sum()/12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c23d71e1ce6d> in <module>
#       1 #atletas = atletas[atletas.status_id==7]#drop(['status_id'], axis=1)
#       2 #atletas = atletas.drop(['status_id'], axis=1)
# ----> 3 dados.iloc[populacao[i]].score_atleta.sum()/12
#
# NameError: name 'dados' is not defined

# %% [markdown]
# # Algoritmo Genético para Escalação Automática

# %%
dados = pd.DataFrame(atletas[['apelido','media','posicao','preco','pontos','jogos']])#.reset_index()
dados.index = dados.index.set_names(['id'])
dados = dados.reset_index()

best = 0
Goleiro = 1
Zagueiro = 2
Zagueiro = 3
Lateral = 4
Lateral = 5
Meia = 6
Meia = 7
Meia = 8
Atacante = 9
Atacante = 10
Atacante = 11
Tecnico = 12

peso_media = 0.5
peso_jogos = 0.25
peso_pontos = 0.25

score_atleta = ((dados.media/dados.media.max()) * peso_media + (dados.jogos/dados.jogos.max()) * peso_jogos 
                + (dados.pontos/dados.pontos.max()) * peso_pontos)/(peso_media+peso_jogos+peso_pontos)
dados['score_atleta'] = score_atleta


# População inicial
populacao = list(range(30))
for i in range(0,30):
    populacao[i]=[random.choice(dados.loc[dados.posicao=='Goleiro']['id']),
                  random.choice(dados.loc[dados.posicao=='Zagueiro']['id']),
                  random.choice(dados.loc[dados.posicao=='Zagueiro']['id']),
                  random.choice(dados.loc[dados.posicao=='Lateral']['id']),
                  random.choice(dados.loc[dados.posicao=='Lateral']['id']),
                  random.choice(dados.loc[dados.posicao=='Meia']['id']),
                  random.choice(dados.loc[dados.posicao=='Meia']['id']),
                  random.choice(dados.loc[dados.posicao=='Meia']['id']),
                  random.choice(dados.loc[dados.posicao=='Atacante']['id']),
                  random.choice(dados.loc[dados.posicao=='Atacante']['id']),
                  random.choice(dados.loc[dados.posicao=='Atacante']['id']),
                  random.choice(dados.loc[dados.posicao=='Tecnico']['id'])]
a = []
c=[]
# Função de custo
for k in range(100):
    b = 107
    for i in range(0,shape(populacao)[0]):
        pontuacao = dados.iloc[populacao[i]].score_atleta.sum()/12
        c.append(pontuacao)
        if dados.iloc[populacao[i]].preco.sum() > b:
            populacao[i].append(100)
        else:
            populacao[i].append(pontuacao)
            if populacao[i][-1]>best:
                best = populacao[i][-1]
                melhor =  populacao[i]
                a.append(populacao[i][-1])
# Seleção
    caixa = populacao
    selecao = []
    for i in range(0,12):
        candidato1 = caixa[random.choice(len(caixa))]
        candidato2 = candidato1
        while (candidato1[0]==candidato2[0]):
            candidato2 = caixa[random.choice(len(caixa))]   #até aqui ok

        if candidato1[-1]>candidato2[-1]:
            selecao.append(candidato1)
            caixa.remove(candidato1)
        else:
            selecao.append(candidato2)
            caixa.remove(candidato2)
# Reprodução
    geracao = []
    while (len(selecao)!=0):
        candidato1 = selecao[random.choice(len(selecao))]
        candidato2 = candidato1
        while (candidato1==candidato2):
            candidato2 = selecao[random.choice(len(selecao))] 
        filho1 = candidato1[0:3]+candidato2[3:6]+candidato1[6:-1]
        pos = random.choice(len(filho1))
        if pos==Goleiro:
            filho1[pos] = random.choice(dados[dados.posicao=='Goleiro'].id)
        elif pos==Zagueiro:
            filho1[pos] = random.choice(dados[dados.posicao=='Zagueiro'].id)
        elif pos==Lateral:
            filho1[pos] = random.choice(dados[dados.posicao=='Lateral'].id)
        elif pos==Meia:
            filho1[pos] = random.choice(dados[dados.posicao=='Meia'].id)
        elif pos==Atacante:
            filho1[pos] = random.choice(dados[dados.posicao=='Atacante'].id)
        else:
            filho1[pos] = random.choice(dados[dados.posicao=='Tecnico'].id)

        filho2 = candidato2[0:3]+candidato1[3:6]+candidato2[6:-1]
        pos = random.choice(len(filho2))
        if pos==Goleiro:
            filho2[pos] = random.choice(dados[dados.posicao=='Goleiro'].id)
        elif pos==Zagueiro:
            filho2[pos] = random.choice(dados[dados.posicao=='Zagueiro'].id)
        elif pos==Lateral:
            filho2[pos] = random.choice(dados[dados.posicao=='Lateral'].id)
        elif pos==Meia:
            filho2[pos] = random.choice(dados[dados.posicao=='Meia'].id)
        elif pos==Atacante:
            filho2[pos] = random.choice(dados[dados.posicao=='Atacante'].id)
        else:
            filho2[pos] = random.choice(dados[dados.posicao=='Tecnico'].id)

        selecao.remove(candidato1)
        selecao.remove(candidato2)
        geracao.append(candidato1[:-1])
        geracao.append(candidato2[:-1])
# Completa população
    populacao = list(range(18))
    for i in range(0,18):
        populacao[i]=[random.choice(dados.loc[dados.posicao=='Goleiro']['id']),
                      random.choice(dados.loc[dados.posicao=='Zagueiro']['id']),
                      random.choice(dados.loc[dados.posicao=='Zagueiro']['id']),
                      random.choice(dados.loc[dados.posicao=='Lateral']['id']),
                      random.choice(dados.loc[dados.posicao=='Lateral']['id']),
                      random.choice(dados.loc[dados.posicao=='Meia']['id']),
                      random.choice(dados.loc[dados.posicao=='Meia']['id']),
                      random.choice(dados.loc[dados.posicao=='Meia']['id']),
                      random.choice(dados.loc[dados.posicao=='Atacante']['id']),
                      random.choice(dados.loc[dados.posicao=='Atacante']['id']),
                      random.choice(dados.loc[dados.posicao=='Atacante']['id']),
                      random.choice(dados.loc[dados.posicao=='Tecnico']['id'])]

    populacao = populacao + geracao
# Time escolhido    
time = pd.DataFrame()
for i in range(12):
    time = time.append(dados[dados.id==melhor[i]])

# %%
time
# Out:
#       id           apelido  media   posicao  preco  pontos  jogos  \
# 63    63            Santos   3.11   Goleiro  12.15     1.0     13
# 108  108  Gustavo Henrique   3.26  Zagueiro   4.96     0.0     10
# 177  177         Lucas Kal   9.10  Zagueiro   3.36     3.5      4
# 52    52    Felipe Jonatan   3.52   Lateral  10.38     6.9     19
# 120  120   Guilherme Arana   5.46   Lateral  11.52    18.0     13
# 99    99      Jadsom Silva   1.11      Meia   2.42     2.0     11
# 73    73        João Paulo   3.75      Meia   8.16     0.0     11
# 51    51           Juninho   2.61      Meia   5.85     1.1     19
# 162  162     Luiz Henrique   3.87  Atacante   6.73    10.0     17
# 8      8             Artur   5.32  Atacante  15.22     0.0     17
# 193  193     Ricardo Bueno   9.05  Atacante  11.38    12.3      6
# 47    47     Abel Ferreira   4.24   Tecnico  12.42     6.5     20
#
#      score_atleta
# 63       0.339530
# 108      0.298168
# 177      0.596230
# 52       0.515430
# 120      0.704762
# 99       0.219719
# 73       0.336996
# 51       0.384875
# 162      0.553907
# 8        0.494689
# 193      0.739515
# 47       0.561340

# %%
time.preco.sum()
# Out:
# 111.62

# %%
plot(a)

# %%
time
# Out:
#       id         apelido  media   posicao  preco  pontos  jogos  score_atleta
# 138  138      João Paulo   3.75   Goleiro   5.14     1.0     14        2.0625
# 43    43   Ricardo Silva   2.60  Zagueiro   3.54     0.0     10        1.3860
# 163  163     João Victor   3.79  Zagueiro   8.00     3.0     18        2.7269
# 154  154             Léo   2.41   Lateral   7.64     0.0     15        1.9151
# 49    49  Abner Vinícius   2.11   Lateral   8.36     5.8     11        2.0801
# 118  118  Matheus Vargas   2.48      Meia   8.48    10.0     18        3.3528
# 173  173          Wagner   3.56      Meia   4.58     3.0      5        1.2716
# 169  169    Yago Pikachu   5.59      Meia  18.80    10.9     18        3.7939
# 38    38         Perotti   2.29  Atacante   6.89     9.2     17        3.1339
# 33    33         Clayson   3.06  Atacante   7.26     5.9     15        2.6356
# 175  175   Luiz Henrique   2.77  Atacante   5.80    10.0     15        3.0547
# 189  189   Diego Aguirre   4.26   Tecnico   8.99     0.0     13        1.8986

# %%
a
# Out:
# [0.4347971357346358,
#  0.44009907916157914,
#  0.48961385836385846,
#  0.49093928062678066]
